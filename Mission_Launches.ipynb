# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishalini15/Vaishalini/blob/Space-Mission-Data-Visualization/Mission_Launches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_data = pd.read_csv("mission_launches.csv")

# %%
df_data.shape
# Out:
# (4324, 9)

# %%
# Before cleaning the data
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14,rotation = 79)
plt.yticks(fontsize=14)
plt.xscale("linear")
plt.xlabel("Organisation Names", color='Blue')
plt.ylabel("Indexes",color='Blue')

plt.bar(df_data['Organisation'],df_data.index,linewidth = 10)
# Out:
# <BarContainer object of 4324 artists>

# %%
df_data.isna()
# Out:
#       Unnamed: 0.1  Unnamed: 0  Organisation  Location   Date  Detail  \
# 0            False       False         False     False  False   False
# 1            False       False         False     False  False   False
# 2            False       False         False     False  False   False
# 3            False       False         False     False  False   False
# 4            False       False         False     False  False   False
# ...            ...         ...           ...       ...    ...     ...
# 4319         False       False         False     False  False   False
# 4320         False       False         False     False  False   False
# 4321         False       False         False     False  False   False
# 4322         False       False         False     False  False   False
# 4323         False       False         False     False  False   False
#
#       Rocket_Status  Price  Mission_Status
# 0             False  False           False
# ...

# %%
duplicate_rows = df_data['Organisation']
# duplicate_rows
df_data[df_data.Organisation == "CASC"]
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 1                1           1         CASC
# 5                5           5         CASC
# 7                7           7         CASC
# 12              12          12         CASC
# 14              14          14         CASC
# ...            ...         ...          ...
# 3110          3110        3110         CASC
# 3215          3215        3215         CASC
# 3375          3375        3375         CASC
# 3471          3471        3471         CASC
# 3509          3509        3509         CASC
#
#                                                Location  \
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 5          LC-9, Taiyuan Satellite Launch Center, China
# 7       LC-101, Wenchang Satellite Launch Center, China
# 12         LC-3, Xichang Satellite Launch Center, China
# 14    Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# ...                                                 ...
# ...

# %%
df_data.isna().values.any()
# Out:
# True

# %%
df_data[df_data.Price.isna()]
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 2                2           2       SpaceX
# 7                7           7         CASC
# 13              13          13          IAI
# 28              28          28       VKS RF
# 31              31          31       ExPace
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                              Location  \
# 2                       Pad A, Boca Chica, Texas, USA
# 7     LC-101, Wenchang Satellite Launch Center, China
# 13                   Pad 1, Palmachim Airbase, Israel
# 28             Site 43/4, Plesetsk Cosmodrome, Russia
# 31    Site 95, Jiuquan Satellite Launch Center, China
# ...                                               ...
# ...

# %%
df_data.dropna(inplace = True)

# %%
df_data.shape
# Out:
# (964, 9)

# %%
# After removing duplicates and NaN
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14,rotation = 79)
plt.yticks(fontsize=14)
plt.xscale("linear")
plt.xlabel("Organisation Names", color='Blue')
plt.ylabel("Indexes",color='Blue')

plt.bar(df_data['Organisation'],df_data.index,linewidth = 10)
# Out:
# <BarContainer object of 964 artists>

# %%
# missions successful and failure counts
df_success = df_data[df_data.Mission_Status == "Failure"].count()
df_success[:5]
# Out:
# Unnamed: 0.1    36
# Unnamed: 0      36
# Organisation    36
# Location        36
# Date            36
# dtype: int64

# %%
arr = np.array[dp_data[dp_data.Price]]
